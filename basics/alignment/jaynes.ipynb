# %% [markdown]
# Attention to constructive relevancies at the same time away from controversial irrelevancies

# %% [markdown]
# A brain, desinged by us, must reason according to certain definite rules. These rules are called desiderata. If our robot does not obey then their thinking needs to be revised or the robot needs to be rejected all together.

# %% [markdown]
# Based on these desiderata we extend our logic. Whether these goals are attainable  without contradictions, and whether they determine any unique extension of logic, are
# matters of mathematical analysis

# %% [markdown]
# Think this way:
# Given any change in the prior information C → C such that B becomes more plausible but A does not.

# %% [markdown]
# # Desidetarum

# %% [markdown]
#  - 1 : Degrees of plausibility are represented by real numbers.
#  - 2 : Qualitative correspondence with common sense.
#  - 3 : structural consistency
#       - A : If a conclusion can be reasoned out in more than one way, then every possible way must lead to the same result.
#       - B : (interface desiderata) The robot always takes into account all of the evidence it has relevant to a question. It does not arbitrarily ignore some of the information, basing its conclusions only on what remains. In other words, the robot is completely nonideological.
#       - C : (interface desiderata) The robot always represents equivalent states of knowledge by equivalent plausibility assignments. That is, if in two problems the robot’s state of knowledge is the same (except perhaps for the labeling of the propositions), then it must assign the same plausibilities in both.

# %% [markdown]
# proof by exhaustion

# %% [markdown]
# (ABC|D) = F{F[(C|D), (B|C D)], (A|BC D)}
#
# read it as:
# - having accepted C is true decide B is true
# - having accepted B is true decide A is true

# %% [markdown]
# ![image.png](attachment:940f07b4-4ea8-4d42-b47b-76a825de344d.png)

# %% [markdown]
# ![image.png](attachment:1f060046-0dd1-48a8-9491-ba8ebceb4eed.png)

# %% [markdown]
# Exhaustive set ::  summation of probabilities is certain i.e. = 1
#
# Mutually exclusive ::  one proposition does not interfere in another proposition's plausibility value. In other words the background information is indifferent to the propositions.
