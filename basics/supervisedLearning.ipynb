# %% [markdown]
# ![image.png](attachment:1434fe2b-81de-48df-a13e-c45fb9eaa76d.png)

# %% [markdown]
# # So what is F?

# %% [markdown]
# CNN, SVM, ConvNet, Recurrent Neural Network, Decision Tree ...
