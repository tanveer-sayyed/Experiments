# %% [markdown]
# # Data
# https://towardsdatascience.com/an-equation-to-code-machine-learning-project-walk-through-in-python-part-1-linear-separable-fd0e19ed2d7

# %%
from pandas import DataFrame
from numpy.random import randn
from matplotlib import pyplot as plt

# %% [markdown]
# ### Create a dummy data to ensure that it is linearly separable

# %%
df = DataFrame({
    "x1":[
        153,220,118,474,485,233,396,484,429,286,
        399,403,252,497,379,76,263,26,61,420,
    ],
    "x2":[
        432,262,214,384,411,430,321,349,259,220,
        433,300,34,372,416,163,112,193,473,253,
    ],
    "y":[
        0,0,0,1,1,0,1,1,1,1,0,1,1,1,0,0,1,0,0,1
    ]
})
plt.scatter(x=df["x1"][df["y"] == 0], y=df["x2"][df["y"] == 0], label="0", marker="o", color="orange")
plt.scatter(x=df["x1"][df["y"] == 1], y=df["x2"][df["y"] == 1], label="1", marker="x", color="gray")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# For a simple linear equation we will use the following code
#
# ![image.png](attachment:d18d806e-cbdd-4805-b4cc-b168188a0104.png)

# %% [markdown]
# The θ mark in the left part means the function f(x) has the parameter theta. θ in the right part means there are two parameters thera-0 and theta-1. But theta-1 will get applied to vector x, which, inturn has two parts - x1 and x2.
#
# So we need 3 theta variables - theta-0 is our bias while theta-1(composing of two elements) is our weight.
#
# So now our equation is:
#
# ![image.png](attachment:f27e2d48-9013-47e8-96ec-7f8b21d168cf.png)

# %% [markdown]
# Its easier to write this equation in vectorized form, like this:
#
# ![image.png](attachment:b73070af-8f46-40e7-b553-1b42e4b46c27.png)

# %% [markdown]
# To achieve this all we have to do is make x0 = 1,
# so that after vectorization we get the same linear equation.
