# %%
import pandas
import multiprocessing

from tqdm import tqdm
from numpy import array
from matplotlib import pyplot as plt

from sklearn import utils
from sklearn.utils import shuffle
from sklearn.base import BaseEstimator
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.metrics.cluster.unsupervised import silhouette_samples, silhouette_score

from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from gensim.parsing.preprocessing import preprocess_string
from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from gensim.parsing.preprocessing import preprocess_string
from pyod.models.lof import LOF

from nltk.cluster import KMeansClusterer, cosine_distance

# %% [markdown]
# ## Defining all classes

# %%
class Doc2VecTransformer(BaseEstimator):
    def __init__(self, vector_size=100, learning_rate=0.02, epochs=20):
        print("From pipeline instantiating Doc2VecTransformer.")
        self.learning_rate = learning_rate
        self.epochs = epochs
        self._model = None
        self.vector_size = vector_size
        self.workers = multiprocessing.cpu_count() - 1
    def fit(self, x, y=None):
        print("From pipeline itting method of Doc2VecTransformer called.")
        # TaggedDocument has a words list and tags list
        tagged_x = [TaggedDocument(preprocess_string(item), [index]) for index, item in enumerate(x)]
        #“Doc2Vec” works really well in understanding the contextual meaning of text
        # (as compared to Tf-Idf which is nothing but pure frequency-based model)
        # Doc2Vec for a document is generated by training a neural network against neighbourhood word
        # of a randomly sampled word and vice versa. 
        model = Doc2Vec(documents=tagged_x, vector_size=self.vector_size, workers=self.workers)
        for epoch in range(self.epochs):
            model.train(shuffle([x for x in tqdm(tagged_x)]), total_examples=len(tagged_x), epochs=1)
            model.alpha -= self.learning_rate
            model.min_alpha = model.alpha
        self._model = model
        return self
    def transform(self, x):
        print("Transform method of Doc2VecTransformer called.")
        arr = array([self._model.infer_vector(preprocess_string(item))
                                     for index, item in enumerate(x)])
        print("Columns of the 2D-array are the actual feature vectors of ‘Doc2Vec’. We have {} columns.".format(arr.shape[1]))
        return arr

class OptimalKMeansTextsClusterTransformer(BaseEstimator):
    def __init__(self, min_k, max_k):
        print("Instantiating OptimalKMeansTextsClusterTransformer.")
        self.min_k = min_k
        self.max_k = max_k
    def fit(self, x, y=None):
        return self
    def _silhouette_score_with_k_(self, vectors, k):
        clusterer = KMeansClusterer(num_means=k, distance=cosine_distance, repeats=3,avoid_empty_clusters=True)
        cluster_labels = clusterer.cluster(vectors=vectors, assign_clusters=True, trace=False)
        silhouette_score_k = silhouette_score(X=vectors, labels=cluster_labels, metric='cosine')
        return k, silhouette_score_k
    def _determine_k_for_max_silhouette_score_(self, process_responses):
        max_silhoutte_score = -100.0
        optimal_k = 2
        for index, process_response in enumerate(process_responses):
            current_k, silhouette_score_k = process_response.get()
            print('Silhoutte Score: ', silhouette_score_k, ' for k', current_k)
            if silhouette_score_k > max_silhoutte_score:
                max_silhoutte_score = silhouette_score_k
                optimal_k = current_k
        return optimal_k

    def transform(self, x):
        print("Transform function of OptimalKMeansTextsClusterTransformer called.")
        range_of_k = [x for x in range(self.min_k, self.max_k)]
        clusterer_pool = multiprocessing.Pool(processes=len(range_of_k))
        clusterer_process_responses = []
        for k in range_of_k:
            clusterer_process_responses.append(clusterer_pool.apply_async(self._silhouette_score_with_k_, args=(x, k,)))

        optimal_k = self._determine_k_for_max_silhouette_score_(process_responses=clusterer_process_responses)
        clusterer_pool.close()
        print("Optimal k: ", optimal_k)
        optimal_clusterer = KMeansClusterer(num_means=optimal_k, distance=cosine_distance, repeats=3)
        optimal_cluster_labels = optimal_clusterer.cluster(vectors=x, assign_clusters=True, trace=False)
        return x, optimal_cluster_labels

# %% [markdown]
# ## Defining all functions

# %%
def _read_all_health_tweets():
    all_tweets = {}
    file = open('Health-Tweets/nytimeshealth.txt', 'r') #place training data here
    lines = file.readlines()
    sublines = lines[:8000]
    for index, line in enumerate(sublines):
        parts = line
        tweet = "".join(parts.replace('\n',''))
        all_tweets[index] = tweet

    file.close()
    return all_tweets
def sort_key(t):
    return t[0]
def plot_tweets_k_means_clusters_with_anomalies(pca_vectors, cluster_labels, pca_vectors_anomalies):
    pca_vectors_anomalies_x = []
    pca_vectors_anomalies_y = []

    for pca_vectors_elem in pca_vectors_anomalies:
        pca_vectors_anomalies_x.append(pca_vectors_elem[1])
        pca_vectors_anomalies_y.append(pca_vectors_elem[0])

    plt.xlabel('Principal Component 2')
    plt.ylabel('Principal Component 1')
    plt.title('Kmeans Cluster of Messages')

    plt.scatter(x=pca_vectors[:, 1], y=pca_vectors[:, 0], c=cluster_labels)
    plt.scatter(x=pca_vectors_anomalies_x, y=pca_vectors_anomalies_y, marker='^')
    plt.show()
def plot_scatter_silhouette_scores(top_n_silhouette_scores, tweets, silhouette_score_per_tweet):
    plt.close('all')
    plt.figure(figsize=(15,10))
    fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)
    fig.suptitle('Silhouette Scores vs Messages')
    sub_plot_scatter_silhouette_scores(ax=ax1, top_n_silhouette_scores=top_n_silhouette_scores,
                                       tweets=tweets,
                                       silhouette_score_per_tweet=silhouette_score_per_tweet,
                                       with_annotation=False)

    sub_plot_scatter_silhouette_scores(ax=ax2, top_n_silhouette_scores=top_n_silhouette_scores,
                                       tweets=tweets,
                                       silhouette_score_per_tweet=silhouette_score_per_tweet,
                                       with_annotation=True)
    plt.show()
    
def sub_plot_scatter_silhouette_scores(ax,top_n_silhouette_scores, tweets, silhouette_score_per_tweet, with_annotation):
    ax.set(xlabel='Message Index', ylabel='Silhouette Score')
    ax.scatter(*zip(*silhouette_score_per_tweet))
    ax.scatter(*zip(*top_n_silhouette_scores), edgecolors='red')

    if with_annotation:
        for (index, score) in top_n_silhouette_scores:
            ax.annotate(tweets['TWEET'][index].index, xy=(index, score), xycoords='data')
def determine_anomaly_tweets_k_means(top_n):
    tweets = _read_all_health_tweets()
    tweets = pandas.DataFrame(data=tweets.values(), index=tweets.keys(), columns=['tweets'], dtype=str)
    tweets = tweets["tweets"].str.split("|", n = 2, expand = True)
    tweets.columns = 'id,timestamp,tweet'.upper().split(',')
    print(tweets.head())
    pipeline = Pipeline(steps=[('doc2vec', Doc2VecTransformer()),
                         ('pca', PCA(n_components=2)),
                         ('kmeans', OptimalKMeansTextsClusterTransformer(min_k=2, max_k=5))])
    pipeline.fit(tweets['TWEET'].values)
    pca_vectors, cluster_labels = pipeline.transform(tweets['TWEET'])
    silhouette_values = silhouette_samples(X=pca_vectors, labels=cluster_labels, metric='cosine')
    tweet_index_silhouette_scores = []
    absolute_silhouette_scores_tweet_index = []

    for index, sh_score in enumerate(silhouette_values):
        absolute_silhouette_scores_tweet_index.append((abs(sh_score), index))
        tweet_index_silhouette_scores.append((index, sh_score))

    sorted_scores = sorted(absolute_silhouette_scores_tweet_index, key=sort_key)

    top_n_silhouette_scores = []
    pca_vectors_anomalies = []
    analomiesIndex = []
    print("Top ", top_n, " anomalies")
    for i in range(top_n):
        abs_sh_score, index = sorted_scores[i]
        index_1, sh_score = tweet_index_silhouette_scores[index]
        top_n_silhouette_scores.append((index, sh_score))
        print(tweets['TWEET'][index])
        analomiesIndex.append(index)
        print('PCA vector', pca_vectors[index])
        pca_vectors_anomalies.append(pca_vectors[index])
        print('Silhouette Score: ', sh_score)
        print("..................")

    plot_tweets_k_means_clusters_with_anomalies(pca_vectors=pca_vectors, pca_vectors_anomalies=pca_vectors_anomalies,
                                                cluster_labels=cluster_labels)
    plot_scatter_silhouette_scores(top_n_silhouette_scores=top_n_silhouette_scores,
                                   tweets=tweets,
                                   silhouette_score_per_tweet=tweet_index_silhouette_scores)
    
    return analomiesIndex

# %%
vectors_df = pipeline.steps[0][1].fit(tweets['TWEET'].values).transform(tweets['TWEET'].values)

# 
print("Dimentionality of vector: ",vectors_df.shape[1])

# %% [markdown]
# # too much features may spoil the actual purpose. So reducing dimensionality
# pca_vectors = pipeline.steps[1][1].fit_transform(vectors_df)
# for index, var in enumerate(pipeline.steps[1][1].explained_variance_ratio_):
#     print("Explained Variance ratio by Principal Component_", (index+1), ": ", var)
# print("\nFirst 2 components explain the maximum variance. So using them.")

# %% [markdown]
# ## Main

# %%
# For outlier detection using ‘Silhoutte Score’(ratio of inter-cluster and intra-cluster distance)  of ‘kmeans’.
# Its value ranges from -1 to 1.
"""
 Value close to -1 : The data point is wrongly put in a cluster to which ideally it should not belong to.
                    Basically it is an ‘inlier’.
 Value close to 0: The data point should not belong to any cluster and should be separated out.
                   It is an ‘outlier’ or ‘anomaly’.
 Value close to 1: The data point is perfectly placed in a right cluster.
"""
# Distances are calculated as inverse of cosine similarity between PCA vectors
# as because it is less sensitive to magnitude & preferable over ‘euclidean’ or generalised ‘minkowski’
# distance for text analytics.
# %matplotlib notebook
anamoliesDetected =  determine_anomaly_tweets_k_means(top_n=100)
# Out:
#                    ID                       TIMESTAMP  \
# 0  548662191340421120  Sat Dec 27 02:10:34 +0000 2014
# 1  548579831169163265  Fri Dec 26 20:43:18 +0000 2014
# 2  548579045269852161  Fri Dec 26 20:40:11 +0000 2014
# 3  548444679529041920  Fri Dec 26 11:46:15 +0000 2014
# 4  548311901227474944  Fri Dec 26 02:58:39 +0000 2014
#
#                                                TWEET
# 0  Risks in Using Social Media to Spot Signs of M...
# 1  RT @paula_span: The most effective nationwide ...
# 2  The New Old Age Blog: Diabetes Prevention That...
# 3  Well: Comfort Casseroles for Winter Dinners ht...
# 4  High-Level Knowledge Before Veterans Affairs S...
# Instantiating Doc2VecTransformer.
# Instantiating OptimalKMeansTextsClusterTransformer.
# Fitting method of Doc2VecTransformer called.
# 100%|██████████| 6245/6245 [00:00<00:00, 1157106.88it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1059819.08it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1345944.63it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1465284.65it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1910255.87it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1360768.27it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 928482.81it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 902505.89it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1380927.27it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1278476.60it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1789168.61it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1370809.53it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1387510.78it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1158027.70it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1187802.85it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1395271.32it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 2006544.24it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 879298.68it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1909420.36it/s]
# 100%|██████████| 6245/6245 [00:00<00:00, 1984050.03it/s]
# Transform method of Doc2VecTransformer called.
# Transform method of Doc2VecTransformer called.
# Transform function of OptimalKMeansTextsClusterTransformer called.
# Silhoutte Score:  0.9134009  for k 2
# Silhoutte Score:  0.9215738  for k 3
# Silhoutte Score:  0.924607  for k 4
# Optimal k:  4
# Top  100  anomalies
# RT @celiadugger: Fear and rage in Guinea: Mob kills journalist and officials at Ebola community awareness event. http://nyti.ms/1r5hEzu
# PCA vector [0.04271439 0.05841115]
# Silhouette Score:  -4.0104016e-05
# ..................
# Letters: Tests for Newborns (1 Letter) http://nyti.ms/1dbYl2G
# PCA vector [-0.09436481  0.09108204]
# Silhouette Score:  0.0013916804
# ..................
# Well: New Doubts About Ginkgo Biloba http://nyti.ms/Y9goyc
# PCA vector [ 0.77963567 -0.3363554 ]
# Silhouette Score:  0.0054678014
# ..................
# Dr. Melvin J. Glimcher, Prosthetics Innovator, Dies at 88 http://nyti.ms/1jCLip1
# PCA vector [ 0.84788215 -0.36591974]
# Silhouette Score:  0.0060561844
# ..................
# RT @cslnyt: Beginning of the end of marijuana prohibition?  http://nyti.ms/1aRw7t3
# PCA vector [-0.02885967 -0.0696186 ]
# Silhouette Score:  -0.006239617
# ..................
# Well: Feeling as if I Failed the Patient http://nyti.ms/UNOQzp
# PCA vector [-0.02205548 -0.05329594]
# Silhouette Score:  -0.007982064
# ..................
# Well: A Cool Classic, Sliced and Diced http://nyti.ms/17E8OQi
# PCA vector [ 0.9898154 -0.4285688]
# Silhouette Score:  0.011842929
# ..................
# The Double-Edged Drug: In Demand in Clinics and on the Street, ‘Bupe’ Can Be Savior or Menace http://nyti.ms/1dEGGxR
# PCA vector [-0.01671977 -0.03952494]
# Silhouette Score:  0.014557907
# ..................
# Obama to Seek Advice on Portal at Tech Meeting http://nyti.ms/1bW2PZp
# PCA vector [-0.0693499   0.06756089]
# Silhouette Score:  -0.017444292
# ..................
# More than four million injuries attributed to extreme sports occurred in the last 10 years. Tips to stay safe: http://nyti.ms/1rYwE35
# PCA vector [-0.04610417 -0.10847927]
# Silhouette Score:  0.019361893
# ..................
# RT @KarenBBarrow: Ever try The Cinnamon Challenge? If not, skip it...Consequences of the 'Cinnamon Challenge' http://nyti.ms/109g3rx
# PCA vector [ 0.24951234 -0.10854394]
# Silhouette Score:  0.020164518
# ..................
# Urbanites Flee China’s Smog for Blue Skies http://nyti.ms/1i32qcP
# PCA vector [-0.0838098  -0.19660376]
# Silhouette Score:  0.022450637
# ..................
# Advertising: Estée Lauder to Weave Pink Ribbons Through the Internet http://nyti.ms/1BX4U3D
# PCA vector [0.5662963 0.7651809]
# Silhouette Score:  -0.023116121
# ..................
# Parents tend to share more bacteria with family dogs than children: http://www.sciencedaily.com/releases/2013/04/130417092140.htm#.UXANk3WkTyc.twitter
# PCA vector [-0.02934558 -0.06864274]
# Silhouette Score:  0.025384877
# ..................
# Well: The Workout: Speedskating With Eddy Alvarez http://nyti.ms/19UuuMf
# PCA vector [ 1.4799263  -0.64631855]
# Silhouette Score:  0.02700665
# ..................
# Partial skull removal to relieve pressure in the brain raises questions about quantity vs quality of life. http://nyti.ms/10XKA0G
# PCA vector [-0.11862454  0.11287281]
# Silhouette Score:  0.030247731
# ..................
# A Gap in the Affordable Care Act http://nyti.ms/1fz6yg0
# PCA vector [-0.43193397  0.42379025]
# Silhouette Score:  -0.031616285
# ..................
# RT @nytimeswell: We're chatting with NYT's Barry Meier at 3:30 about pain treatment, pills &amp; the opioid boom. Tweet your questions to @nyti…
# PCA vector [-0.0469299  0.0460995]
# Silhouette Score:  -0.033952177
# ..................
# Well: Think Like a Doctor: Mirror, Mirror Solved! http://nyti.ms/1pN0KSp
# PCA vector [0.07510821 0.10074481]
# Silhouette Score:  -0.037040096
# ..................
# Business Briefing: F.D.A. Approves New Version of Cervical Cancer Vaccine  http://nyti.ms/1qyieJt
# PCA vector [-0.32851052 -0.81806517]
# Silhouette Score:  -0.03773789
# ..................
# The New Old Age Blog: Study Finds Wives Often Struggle With Stepchildren Over Caregiving http://nyti.ms/GZQM1W
# PCA vector [-0.02901799 -0.06681899]
# Silhouette Score:  0.04140884
# ..................
# RT @cslnyt: Are you so stressed you've got pseudodementia? http://nyti.ms/11chwCB
# PCA vector [-0.04434577  0.04389292]
# Silhouette Score:  -0.04881619
# ..................
# Medicare Proposes Paying for Lung Cancer Screenings for Older Longtime Smokers http://nyti.ms/1ugQgRZ
# PCA vector [-0.09293785  0.08756539]
# Silhouette Score:  0.049660914
# ..................
# Reactions: Ebola, Nurses for Africa, Seafood Apps, a Doctor’s Honor http://nyti.ms/1pFVSmq
# PCA vector [ 0.2667309  -0.11823121]
# Silhouette Score:  0.052754648
# ..................
# Well: Ask Well: Gap Toothed http://nyti.ms/1ekd7FO
# PCA vector [ 0.8707759  -0.38645735]
# Silhouette Score:  0.054871745
# ..................
# Well: Weight Gain Carries Risks, No Matter Your Weight http://nyti.ms/1zHKkDH
# PCA vector [-0.047237    0.04438189]
# Silhouette Score:  0.05511755
# ..................
# Op-Ed Contributor: How the Big Tobacco Deal Went Bad http://nyti.ms/1s5WfZa
# PCA vector [-0.00925091 -0.02101542]
# Silhouette Score:  0.055158976
# ..................
# Can you figure out what's wrong with of a woman who has a stomach ailment identical to one she suffered years ago? http://nyti.ms/1kZWY8u
# PCA vector [-0.02807492 -0.06369724]
# Silhouette Score:  0.056445427
# ..................
# Global Health: How Fighting in Pakistan Affects War Against Polio http://nyti.ms/1tUaxvQ
# PCA vector [-0.09301143  0.08727479]
# Silhouette Score:  0.057668496
# ..................
# Letters: Hpv Vaccines for Boys http://nyti.ms/YX5IzE
# PCA vector [-0.03267014  0.03248512]
# Silhouette Score:  -0.057677668
# ..................
# MT @sangerkatz: There's no treatment or vaccine for Guinea worm. But worldwide eradication close. http://nyti.ms/XWX76p
# PCA vector [-0.3552032 -0.9089726]
# Silhouette Score:  -0.0633679
# ..................
# Turning a patient into a "zombie" to save his life? Doctors are planning to try this procedure soon: http://nyti.ms/1ih4SHY
# PCA vector [-0.04432213  0.04429462]
# Silhouette Score:  0.06411909
# ..................
# Q&amp;A: Taking More Than One Vaccine at a Time Doesn't Hurt http://nyti.ms/1vjittH
# PCA vector [-0.3795978 -0.9772634]
# Silhouette Score:  -0.06886501
# ..................
# Well: Small Grains, Big Nutrition http://nyti.ms/16okB3s
# PCA vector [ 0.32392144 -0.13371852]
# Silhouette Score:  -0.07003603
# ..................
# Two Vaccines to Protect Against Ebola Could Be Available Within Weeks  http://nyti.ms/1qD2ykB
# PCA vector [-0.38536522 -0.9948677 ]
# Silhouette Score:  -0.07137923
# ..................
# AIDS Vaccine Path Suggested by Study http://nyti.ms/14ENbiA
# PCA vector [-0.40083796 -1.0351837 ]
# Silhouette Score:  -0.07170339
# ..................
# Letters: A Mixed Bag in H.I.V. Prevention (1 Letter) http://nyti.ms/1iLhfAa
# PCA vector [-0.04354418  0.04369563]
# Silhouette Score:  0.071895294
# ..................
# Food for Thought: Calories on Menus: Nationwide Experiment Into Human Behavior http://nyti.ms/11VFtSQ
# PCA vector [-0.12835465  0.12891014]
# Silhouette Score:  0.07349447
# ..................
# "Before the visit, I had been split in two not by fear of death but by dread of dying.” A hospice tour:  http://nyti.ms/1pfovFB
# PCA vector [-0.01573598 -0.04075022]
# Silhouette Score:  -0.0741684
# ..................
# The New Old Age Blog: ‘Somebody That Nobody Thought I Could Be’ http://nyti.ms/1d0cxuR
# PCA vector [-0.07872523  0.07323725]
# Silhouette Score:  0.074193574
# ..................
# Well: Dress Up Your Salad With Grains http://nyti.ms/146mzIk
# PCA vector [ 0.7988094 -0.3286331]
# Silhouette Score:  -0.07557978
# ..................
# Well: A Fat Dad Halloween (Hide the Candy) http://nyti.ms/1f5aogl
# PCA vector [ 0.22410205 -0.09191018]
# Silhouette Score:  -0.08058829
# ..................
# RT @dacorc: Amazing pix of non-twin lookalikes (for a psychology study). http://nyti.ms/1mK8qEL
# PCA vector [-0.02000631 -0.04417717]
# Silhouette Score:  0.08377353
# ..................
# Well: Where Germs Hide in Your Kitchen http://nyti.ms/ZQnDY5
# PCA vector [ 1.2996802 -0.5883245]
# Silhouette Score:  0.08826719
# ..................
# Legal Use of Marijuana Clashes With Job Rules http://nyti.ms/1lLZdRm
# PCA vector [-0.04586585  0.04227999]
# Silhouette Score:  0.091470644
# ..................
# Experimental Vaccine Shows Promise Against Dengue Fever http://nyti.ms/1nxgsBi
# PCA vector [-0.4376162 -1.1579906]
# Silhouette Score:  -0.09321807
# ..................
# Study Examines Efficacy of Taxes on Sugary Drinks http://nyti.ms/1mHHndz
# PCA vector [-0.02250122 -0.04913112]
# Silhouette Score:  0.09502538
# ..................
# Texas Abortion Clinic to Reopen After Court Ruling http://nyti.ms/1r2D7WW
# PCA vector [-0.06236724  0.05732468]
# Silhouette Score:  0.09688751
# ..................
# Doctors Without Borders has sent 700 doctors &amp; aid workers to Ebola-stricken countries http://nyti.ms/ZKpc18 http://pbs.twimg.com/media/B0-MG_jCQAAkg_o.png
# PCA vector [0.70609146 0.91410834]
# Silhouette Score:  -0.10215556
# ..................
# Michael Douglas said he developed throat cancer from H.P.V. Why isn't there a way to screen men for this virus? http://nyti.ms/13v8AGW
# PCA vector [ 2.5661144 -1.0358086]
# Silhouette Score:  -0.10569111
# ..................
# Roche Abandons New Diabetes Drug http://nyti.ms/1aYcqPV
# PCA vector [-0.01140506 -0.03063539]
# Silhouette Score:  -0.106038906
# ..................
# RT @DrFriedenCDC: Local public health officials in TX have begun identifying close contacts of #Ebola patient for further monitoring. http:…
# PCA vector [-0.05246405 -0.11315737]
# Silhouette Score:  0.107257605
# ..................
# The New Old Age Blog: ‘Aid in Dying’ Sentiment Gathers Momentum http://nyti.ms/1lcazJQ
# PCA vector [-0.02499286 -0.06732115]
# Silhouette Score:  -0.10838303
# ..................
# The New Old Age Blog: At Too Many Hospitals, a Revolving Door http://nyti.ms/18xW6lC
# PCA vector [-0.03471239 -0.07460385]
# Silhouette Score:  0.110791296
# ..................
# The New Old Age: A Shortage of Caregivers http://nyti.ms/1mHHyKi
# PCA vector [-0.04214154  0.04321137]
# Silhouette Score:  0.111787096
# ..................
# The average ice bucket challenge gift size was $46.25, with the largest donation so far being a $100,000 check. http://nyti.ms/1loHhME
# PCA vector [-0.18577756 -0.50261354]
# Silhouette Score:  -0.11205262
# ..................
# Living With Uncertainty: Expected Health Spending Declines — Again http://nyti.ms/1mfqPI1
# PCA vector [-0.02158163 -0.05841323]
# Silhouette Score:  -0.11240924
# ..................
# Remaking Medicine: New Law’s Demands on Doctors Have Many Seeking a Network http://nyti.ms/1hzCNxF
# PCA vector [-0.04565875  0.04688122]
# Silhouette Score:  0.114222236
# ..................
# National Briefing | New England: Massachusetts: Sex-Change Surgery Denied to Inmate http://nyti.ms/13aAYn0
# PCA vector [0.13078745 0.19054557]
# Silhouette Score:  0.114337265
# ..................
# Some Will Get An Extension On Insurance  http://nyti.ms/1gA2HCS
# PCA vector [ 1.0439855  -0.48212805]
# Silhouette Score:  0.12112543
# ..................
# RT @celiadugger: Odds of getting Ebola on a flight? Not high, even if asymptomatic person with Ebola aboard. http://nyti.ms/1D89PhY
# PCA vector [-0.0834495  -0.17738879]
# Silhouette Score:  0.12168317
# ..................
# The New Old Age Blog: A Rising Tide of Mental Distress http://nyti.ms/12KknBT
# PCA vector [-0.16040243  0.14530233]
# Silhouette Score:  0.123603135
# ..................
# Dispatch: Ebola Should Be Easy to Treat http://nyti.ms/1xyIZQn
# PCA vector [-0.09134037 -0.25104284]
# Silhouette Score:  -0.12500669
# ..................
# RT @paula_span: Paid leave for childcare and eldercare? Two Democratic congresswomen launch campaign to support working caregivers. http://…
# PCA vector [-0.04383587  0.03963197]
# Silhouette Score:  0.1271181
# ..................
# Well: Think Like a Doctor: Sweating It Solved! http://nyti.ms/1lcPJKj
# PCA vector [-0.13289005 -0.2808269 ]
# Silhouette Score:  0.12749442
# ..................
# Are you a female veteran? Has the return to civilian life been hard? We want to hear from you. http://nyti.ms/WM3Yzf
# PCA vector [-0.0760171   0.06855264]
# Silhouette Score:  0.13168298
# ..................
# Doctors Who Profit From Radiation Prescribe It More Often, Study Finds http://nyti.ms/14sr8aA
# PCA vector [-0.02252484 -0.04736587]
# Silhouette Score:  0.13235398
# ..................
# Well: Ask Well: How Long Does a Flu Shot Last? http://nyti.ms/1b3uLLh
# PCA vector [-0.02504329 -0.06951781]
# Silhouette Score:  -0.13300304
# ..................
# Books: Josephine Baker’s ‘Fighting for Life’ Still Thought-Provoking Decades Later http://nyti.ms/Hcl0hw
# PCA vector [-0.07188316  0.06477153]
# Silhouette Score:  0.13315083
# ..................
# RT @carlzimmer: A look at WHO’s shortcomings in the face of #Ebola http://www.nytimes.com/2014/09/04/world/africa/cuts-at-who-hurt-response-to-ebola-crisis.html?_r=0 Slashed, quirky budget, for one thing.
# PCA vector [-0.05950239  0.06185181]
# Silhouette Score:  0.13604571
# ..................
# Lens Blog: Five Minutes That Split Lifetimes http://nyti.ms/18xpHuJ
# PCA vector [ 0.1493016  -0.06969704]
# Silhouette Score:  0.13844492
# ..................
# Ask Well: Do Monogamous Women Still Need a Pap Smear? http://nyti.ms/SsLIIi
# PCA vector [-0.03983321  0.04149065]
# Silhouette Score:  0.13961071
# ..................
# Do you know the correct way to apply sunscreen? Hint: you're probably doing it incorrectly. http://nyti.ms/18uM6sX
# PCA vector [-0.04327788  0.04511114]
# Silhouette Score:  0.14086513
# ..................
# RT @KJDellAntonia: Join @NYTMotherlode and @BethBDaley tomorrow 2p 4 live chat re:: the impact of Oversold prenatal tests http://t.co/0LsXh…
# PCA vector [ 1.8741368 -0.8766105]
# Silhouette Score:  0.14158031
# ..................
# Overdoses involving prescription drugs are a leading cause of accidental death in the United States. http://nyti.ms/1uj8yPe
# PCA vector [-0.04466701  0.04672622]
# Silhouette Score:  0.1470715
# ..................
# Well: A New Way to Make Pizza http://nyti.ms/14XS5DR
# PCA vector [-0.35394704  0.3154892 ]
# Silhouette Score:  0.15235639
# ..................
# Well: A Headbanger’s Headache http://nyti.ms/1miDa2W
# PCA vector [ 0.52879    -0.20674142]
# Silhouette Score:  -0.15338035
# ..................
# Enjoying inflicting pain without provocation? You, too, may be an “everyday sadist.” http://nyti.ms/1aHW6k9
# PCA vector [-0.04300243  0.0452521 ]
# Silhouette Score:  0.1572224
# ..................
# Well: A Lifeline for Widowed Fathers http://nyti.ms/11y7ucA
# PCA vector [ 0.14087605 -0.05479117]
# Silhouette Score:  -0.16087343
# ..................
# The gluten-free diet market expected to reach $15 billion in annual sales by 2016. http://nyti.ms/1xD4XhP
# PCA vector [-0.11059476  0.11692838]
# Silhouette Score:  0.16517846
# ..................
# Well: My Father’s A.L.S. http://nyti.ms/1sZNADA
# PCA vector [-0.06636204  0.05870036]
# Silhouette Score:  0.16566534
# ..................
# Well: A Science Project With Legs http://nyti.ms/1b7zuag
# PCA vector [-0.04374626  0.04627601]
# Silhouette Score:  0.1660691
# ..................
# Well: Helping Smokers Quit, or Not Start in the First Place http://nyti.ms/1e1qyu2
# PCA vector [-0.03331828  0.02945474]
# Silhouette Score:  0.16665158
# ..................
# RT @lpolgreen: Who should get experimental Ebola serum? Not as easy to answer as you’d think. http://www.nytimes.com/2014/08/09/health/in-ebola-outbreak-who-should-get-experimental-drug.html?ref=world&_r=0
# PCA vector [-0.05547141 -0.11212008]
# Silhouette Score:  0.17096627
# ..................
# World Briefing: Turkey: MERS Virus Case Is Reported http://nyti.ms/1wo6Npm
# PCA vector [ 0.7730946  -0.29841167]
# Silhouette Score:  -0.17157559
# ..................
# RT @bcsolomon: A health worker checks himself in a mirror before entering highly contagious #Ebola ward. At @MSF clinic in #Liberia http://…
# PCA vector [ 0.31807417 -0.15193535]
# Silhouette Score:  0.17446023
# ..................
# F.D.A. Approves Hysingla, a Powerful Painkiller http://nyti.ms/1uNubex
# PCA vector [-0.01547243 -0.03115235]
# Silhouette Score:  0.1747067
# ..................
# Why is chocolate so good for us? http://nyti.ms/1roxFOA
# PCA vector [-0.03836251 -0.0771153 ]
# Silhouette Score:  0.1762588
# ..................
# Salmonella in Spices Prompts Changes in Farming http://nyti.ms/17kvAfG
# PCA vector [0.05091236 0.07711567]
# Silhouette Score:  0.17651033
# ..................
# RT @cslnyt: The fight against "vacation cutting," when U.S. girls get sent abroad to be mutilated. http://nyti.ms/1oSy38f
# PCA vector [ 0.9871311 -0.4740275]
# Silhouette Score:  0.18257949
# ..................
# Well: The CPR We Don’t See on TV http://nyti.ms/1mXXne1
# PCA vector [ 1.1113977 -0.536454 ]
# Silhouette Score:  0.19041072
# ..................
# Kathryn Morgan Uses Social Media as She Gears for Her Return http://nyti.ms/1AoEKDl
# PCA vector [-0.01565441 -0.0469515 ]
# Silhouette Score:  -0.19078693
# ..................
# Happiness Inc. http://nyti.ms/11sivwd
# PCA vector [ 1.0252569  -0.38957414]
# Silhouette Score:  -0.19320549
# ..................
# What is enterovirus 68? http://nyti.ms/1ok2gvV
# PCA vector [0.17509457 0.21453062]
# Silhouette Score:  -0.19622642
# ..................
# RT @celiadugger: Ebola goes viral on Twitter. Why do some topics -- shark attacks, dread diseases - become social contagions of fear? http:…
# PCA vector [0.58855563 0.904521  ]
# Silhouette Score:  0.1983232
# ..................
# Brown Rice Bowl With Oven-Baked Miso-Glazed Tofu, Red Peppers and Kimchi http://nyti.ms/17s7Bw4
# PCA vector [-0.10342524  0.08960331]
# Silhouette Score:  0.20077185
# ..................
# King Richard III quite enjoyed devouring swan, crane and heron with a side of wine. http://nyti.ms/1olYlgM
# PCA vector [ 1.6572564 -0.807327 ]
# Silhouette Score:  0.20426685
# ..................
# F.D.A. Approves a Drug for Late-Stage Pancreatic Cancer http://nyti.ms/17HficU
# PCA vector [-0.08311085  0.08999283]
# Silhouette Score:  0.20435034
# ..................
# Well: Women Find Orgasms Elusive in Hookups http://nyti.ms/1dZ7E49
# PCA vector [ 0.21209073 -0.07965866]
# Silhouette Score:  -0.20871373
# ..................
# Well: When Children Pose a Danger to Parents http://nyti.ms/163foBx
# PCA vector [-0.03965274  0.04313362]
# Silhouette Score:  0.21164481
# ..................
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="640">
